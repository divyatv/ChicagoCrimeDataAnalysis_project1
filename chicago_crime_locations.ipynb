# %%
##################################################
#### Divya TV June 2019
#################################################

###Import required libraries####################################
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

########################################################################

# %%
#### Load the CSV files and Initialize dataframes.#####################
## Provide path to the files.
# File to Load (Remember to change these)
city_data_to_load = "Crimes2001_to_present.csv"

## Load the CSV files.
# Read the City and Ride Data from CSV file
#city_data=pd.DataFrame()
city_data = pd.read_csv(city_data_to_load)


##Initialize th dataframes 
city_datadf=pd.DataFrame(city_data)


# Display the data table for preview
#city_datadf.head()

#Location Description
#### NO need to run this code block everytime - the data has been fed into smaller csv already

# %%
city_datadf.shape
# Out:
# (6900774, 30)

# %%
city_datadf_remove_dup=city_datadf.drop_duplicates(subset='ID', keep='first', inplace=False)
city_datadf_remove_dup.head(20)
# Out:
#           ID Case Number                    Date                      Block  \
# 0   11728853    JC313799  06/19/2019 11:58:00 PM          018XX N MASON AVE
# 1   11730014    JC313807  06/19/2019 11:55:00 PM       084XX S MICHIGAN AVE
# 2   11728939    JC313822  06/19/2019 11:55:00 PM           005XX W OHARE ST
# 3   11728854    JC313820  06/19/2019 11:50:00 PM  091XX S COTTAGE GROVE AVE
# 4   11729798    JC314900  06/19/2019 11:50:00 PM            002XX W 93RD ST
# 5   11730504    JC315639  06/19/2019 11:50:00 PM           035XX N CLARK ST
# 6   11728945    JC313812  06/19/2019 11:49:00 PM             068XX S MAY ST
# 7   11730495    JC315739  06/19/2019 11:45:00 PM            0000X E OHIO ST
# 8   11728836    JC313827  06/19/2019 11:45:00 PM        044XX S KEDVALE AVE
# 9   11729213    JC314302  06/19/2019 11:40:00 PM       012XX W JACKSON BLVD
# 10  11735243    JC321740  06/19/2019 11:30:00 PM          022XX W WALTON ST
# ...

# %%
city_datadf_remove_dup.shape
# Out:
# (6900774, 30)

# %%
#drop all records which have long and lat as NaN

#city_datadf_remove_dup_remove_null_geo=city_datadf_remove_dup.loc[['Longitude']== NaN

# %%
import gmaps
crime_data= city_datadf_remove_dup.loc[(city_datadf_remove_dup['Primary Type']== 'THEFT') | (city_datadf_remove_dup['Primary Type']== 'ASSAULT')| 
                                      (city_datadf_remove_dup['Primary Type']== 'BURGLARY') |
                                       (city_datadf_remove_dup['Primary Type']== 'MOTOR VEHICLE THEFT'),:]
                                       
#'ASSAULT', 'BURGLARY', 'MOTOR VEHICLE THEFT'), :]
crime_datadf=pd.DataFrame(crime_data)
crime_datadf = crime_datadf.dropna()
crime_datadf.to_csv("crime_datadf_only4.csv", index = None, header=True)
#crime_datadf.head(10)

#Loading CSV file using pandas
file_to_load = "crime_datadf_only4.csv"

#printing the path of the file
print ("path of the file", file_to_load)

# Read Purchasing File and store into Pandas data frame
crimedatadf4 = pd.read_csv(file_to_load)

#(city_crime_data_df['Year'] > 2010) & (city_crime_data_df['Year'] < 2016), :
# Out:
# path of the file crime_datadf_only4.csv

# %%
crimedatadf4.shape
# Out:
# (2276468, 30)

# %%
crimedatadf4['Date'] = pd.to_datetime(crimedatadf4['Date'])

start_date = '07-01-2002'
end_date = '04-01-2019'

mask = (crimedatadf4['Date'] > start_date) & (crimedatadf4['Date'] <= end_date)

crimedatadf4 = crimedatadf4.loc[mask]
crimedatadf4.head(10)

crimedatadf4.to_csv("crimedatadf4.csv", index = None, header=True)

# %%
#Loading CSV file using pandas
file_to_load = "crimedatadf4.csv"

#printing the path of the file
print ("path of the file", file_to_load)

# Read Purchasing File and store into Pandas data frame
crime_datadf4 = pd.read_csv(file_to_load)
# Out:
# path of the file crimedatadf4.csv

# %%
import gmplot 


##Syntax for to list
#Products_list = df.values.tolist()
#AveragePurchasePrice=list(Summary_table_transposed['Average Purchase Price'])

lat_list=list(crime_datadf4['Latitude'])
lng_list=list(crime_datadf4['Longitude'])

# print("lat list=", lat_list)
# print("lng_list=",lng_list )

# #declare the center of the map, and how much we want the map zoomed in
gmap = gmplot.GoogleMapPlotter(41.881832, -87.623177, 13)
# # API key
gmap.apikey = 'AIzaSyAmpcf4PCVP54Sw3R_macfn8oA00_jaeGc'
## I dont need connecting lines
#gmap.plot(lat_list, lng_list, 'cornflowerblue', edge_width=10)
#gmap.scatter(lat_list, lng_list, '#3B0B39', size=40, marker=False)
#gmap.scatter(marker_lats, lng_list, 'k', marker=True)
gmap.heatmap(lat_list,lng_list)

## Save html file
gmap.draw("crime_datadf4.html")

print("Im done plotting check the crime_datadf4.html file")
# Out:
# Im done plotting check the crime_datadf4.html file

# %%
theft_datadf['Date'] = pd.to_datetime(theft_datadf['Date'])

start_date = '07-01-2002'
end_date = '04-01-2019'

mask = (theft_datadf['Date'] > start_date) & (theft_datadf['Date'] <= end_date)

theft_datadf = theft_datadf.loc[mask]
theft_datadf.head(10)

theft_datadf.to_csv("Theft_data_date_range.csv", index = None, header=True)

# %%
import gmaps
theft_data= city_datadf_remove_dup.loc[(city_datadf_remove_dup['Primary Type']== 'THEFT'), :]
theft_datadf=pd.DataFrame(theft_data)
#theft_datadf.head()

theft_datadf.to_csv("Theft_data.csv", index = None, header=True)

theft_count=theft_datadf['ID'].count()
print("theft count=", theft_count)

# Drop all the rows which have null values

theft_datadf = theft_datadf.dropna()
#theft_datadf = theft_datadf.drop(columns=['Unnamed: 0', 'ID', 'Case Number', 'Block', 'IUCR','Domestic', 'Beat', 'District','X Coordinate', 'Y Coordinate','Updated On', 'FBI Code'], axis = 1)

#theft_datadf.head(30)
# Out:
# theft count= 1453930
#              ID Case Number                    Date                    Block  \
# 22370  11694353    JC271942  05/21/2019 09:50:00 AM     043XX W FERDINAND ST
# 22412  11694270    JC271825  05/21/2019 08:30:00 AM         032XX N BROADWAY
# 22432  11694368    JC271947  05/21/2019 08:00:00 AM         018XX S CANAL ST
# 22468  11694221    JC271701  05/21/2019 04:44:00 AM        049XX W NELSON ST
# 22473  11694279    JC271799  05/21/2019 04:30:00 AM    065XX N WASHTENAW AVE
# 22483  11694200    JC271695  05/21/2019 03:50:00 AM       001XX S HALSTED ST
# 22490  11694213    JC271698  05/21/2019 02:59:00 AM      016XX N LARRABEE ST
# 22494  11694400    JC271929  05/21/2019 02:30:00 AM       0000X W HUBBARD ST
# 22513  11694243    JC271691  05/21/2019 01:21:00 AM      092XX S KIMBARK AVE
# 22522  11694138    JC271640  05/21/2019 12:10:00 AM  050XX W WASHINGTON BLVD
# 22524  11694136    JC271648  05/21/2019 12:01:00 AM    064XX N FRANCISCO AVE
# ...

# %%
## get data for last 12 months.
theft_datadf['Date'] = pd.to_datetime(theft_datadf['Date'])

start_date = '07-01-2002'
end_date = '04-01-2019'

mask = (theft_datadf['Date'] > start_date) & (theft_datadf['Date'] <= end_date)

theft_datadf = theft_datadf.loc[mask]
theft_datadf.head(10)

theft_datadf.to_csv("Theft_data_date_range.csv", index = None, header=True)

# %%
# Configure gmaps with API key
# gmaps.configure(api_key="AIzaSyAmpcf4PCVP54Sw3R_macfn8oA00_jaeGc")

#DataFrame.reindex(labels=None, index=None, columns=None, axis=None, 
#method=None, copy=True, level=None, fill_value=nan, limit=None, tolerance=None)[source]
# theft_datadf=theft_datadf.set_index('Date')
#DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)[source]

# theft_datadf.truncate(after='2019-03-31' , before='2018-07-01')
theft_datadf.shape
theft_datadf.index



#Loading CSV file using pandas
file_to_load = "Theft_data_date_range.csv"

#printing the path of the file
print ("path of the file", file_to_load)

# Read Purchasing File and store into Pandas data frame
theftdata_df = pd.read_csv(file_to_load)

## If you want a subset of the dataframe to mange the api calls
#theftdata_df=theft_datadf[1:10]
#print(theftdate_df)
theftdata_df.shape


# Convert Poverty Rate to float and store
# HINT: be sure to handle NaN values
# Out:
# path of the file Theft_data_date_range.csv
# (46990, 30)

# %%
import gmplot 


##Syntax for to list
#Products_list = df.values.tolist()
#AveragePurchasePrice=list(Summary_table_transposed['Average Purchase Price'])

lat_list=list(theftdata_df['Latitude'])
lng_list=list(theftdata_df['Longitude'])

# print("lat list=", lat_list)
# print("lng_list=",lng_list )

# #declare the center of the map, and how much we want the map zoomed in
gmap = gmplot.GoogleMapPlotter(41.881832, -87.623177, 13)
# # API key
gmap.apikey = 'AIzaSyAmpcf4PCVP54Sw3R_macfn8oA00_jaeGc'
## I dont need connecting lines
#gmap.plot(lat_list, lng_list, 'cornflowerblue', edge_width=10)
#gmap.scatter(lat_list, lng_list, '#3B0B39', size=40, marker=False)
#gmap.scatter(marker_lats, lng_list, 'k', marker=True)
gmap.heatmap(lat_list,lng_list)

## Save html file
gmap.draw("theft_date_range.html")

print("Im done plotting check the theft_date_range.html file")
# Out:
# Im done plotting check the theft_date_range.html file

# %%
# Out:
#   <div class="bk-root" id="a6442cc8-bf23-41d5-8933-bc6b369da2f2" data-root-id="1505"></div>

# %% [markdown]
# ## Count Assault and other counts

# %%
assault_data= city_datadf_remove_dup.loc[(city_datadf_remove_dup['Primary Type']== 'ASSAULT'), :]
assault_datadf=pd.DataFrame(assault_data)
#assault_data.head()

assault_datadf.to_csv("assault_data.csv", index = None, header=True)

assault_count=assault_datadf['ID'].count()
print("assault count=", assault_count)

assault_datadf = assault_datadf.dropna()
# Out:
# assault count= 430611

# %%
## get data for last 12 months.
assault_datadf['Date'] = pd.to_datetime(assault_datadf['Date'])

start_date = '07-01-2002'
end_date = '04-01-2019'

mask = (assault_datadf['Date'] > start_date) & (assault_datadf['Date'] <= end_date)

assault_datadf = assault_datadf.loc[mask]
assault_datadf.head(10)

assault_datadf.to_csv("Assault_data_date_range.csv", index = None, header=True)

# %%
#Loading CSV file using pandas
file_to_load = "Assault_data_date_range.csv"

#printing the path of the file
print ("path of the file", file_to_load)

# Read Purchasing File and store into Pandas data frame
assaultdatadf = pd.read_csv(file_to_load)

## If you want a subset of the dataframe to mange the api calls
#theftdata_df=theft_datadf[1:10]
#print(theftdate_df)
assaultdatadf.shape
# Out:
# path of the file Assault_data_date_range.csv
# (375759, 30)

# %%
import gmplot 
import gmaps
from ipywidgets.embed import embed_minimal_html

##Syntax for to list
#Products_list = df.values.tolist()
#AveragePurchasePrice=list(Summary_table_transposed['Average Purchase Price'])

lat_list=list(assaultdatadf['Latitude'])
lng_list=list(assaultdatadf['Longitude'])
location=zip(lat_list, lng_list)

# print("lat list=", lat_list)
# print("lng_list=",lng_list )

# #declare the center of the map, and how much we want the map zoomed in
#heatmap = gmplot.GoogleMapPlotter(41.881832, -87.623177, 13)
# # API key
#heatmap.apikey = 'AIzaSyAmpcf4PCVP54Sw3R_macfn8oA00_jaeGc'
## I dont need connecting lines
#gmap.plot(lat_list, lng_list, 'cornflowerblue', edge_width=10)
#gmap.scatter(lat_list, lng_list, '#3B0B39', size=40, marker=False)
#gmap.scatter(marker_lats, lng_list, 'k', marker=True)
#RGBA
# #gradient=[#0000FF,#800000,#00FFFF,#FFFF00]
# #heatmap.gradient = [
#     'white',
#     'silver',
#     'gray'



# >>> heatmap.max_intensity = 2
# >>> heatmap.point_radius = 3


# gmaps.configure(api_key="AIzaSyAmpcf4PCVP54Sw3R_macfn8oA00_jaeGc")
# fig = gmaps.figure(center=(41.881832, -87.623177), zoom_level=8)
# fig=gmaps.heatmap_layer(location)
# fig.gradient = ['blue', 'red']
# fig.add_layer(heatmap)
# fig.draw("chicago.html")
# #heatmap.figure()
# embed_minimal_html("export.html", views=[fig])


print("Im done plotting check the assault_date_range.html file")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d67d0cf9f110> in <module>
#      39 fig=gmaps.heatmap_layer(location)
#      40 fig.gradient = ['blue', 'red']
# ---> 41 fig.add_layer(heatmap)
#      42 fig.draw("chicago.html")
#      43 #heatmap.figure()
#
# AttributeError: 'Heatmap' object has no attribute 'add_layer'

# %%
vehicletheft_data= city_datadf_remove_dup.loc[(city_datadf_remove_dup['Primary Type']== 'MOTOR VEHICLE THEFT'), :]
vehicletheft_datadf=pd.DataFrame(vehicletheft_data)
#vehicletheft_data.head()

vehicletheft_datadf.to_csv("vehicletheft_data.csv", index = None, header=True)
vehicletheft_count=vehicletheft_datadf['ID'].count()
print("vehicletheft count=", vehicletheft_count)
# Out:
# vehicletheft count= 319687

# %%
# Out:
# arrests count= 0

# %%
burglary_data= city_datadf_remove_dup.loc[(city_datadf_remove_dup['Primary Type']== 'BURGLARY'), :]
burglary_datadf=pd.DataFrame(burglary_data)
#burglary_datadf.head()

burglary_datadf.to_csv("burglary_data.csv", index = None, header=True)


burglary_datadf.to_csv("burglary_data.csv", index = None, header=True)
burglary_count=burglary_datadf['ID'].count()
print("burglary count=", burglary_count)
# Out:
# burglary count= 393687

# %%
plt.figure(figsize = (15, 10))
sns.countplot(y= 'Location Description', data = burglary_datadf, order = burglary_datadf['Location Description'].value_counts().iloc[:10].index)
